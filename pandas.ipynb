# %%
import pandas as pd

# %%
pwd
# Out:
# 'C:\\MyStuff\\Ddrive\\Tensorflow\\Tensorflow-Bootcamp\\crash-course'

# %%
df = pd.read_csv('salaries.csv')

# %%
df
# Out:
#      Name  Salary  Age
# 0    John   50000   34
# 1   Sally  120000   45
# 2  Alyssa   80000   27

# %%
df['Salary']
# Out:
# 0     50000
# 1    120000
# 2     80000
# Name: Salary, dtype: int64

# %%
df[['Salary', 'Name']]
# Out:
#    Salary    Name
# 0   50000    John
# 1  120000   Sally
# 2   80000  Alyssa

# %% [markdown]
# for some statistics about the data in table

# %%
df.describe()
# Out:
#               Salary        Age
# count       3.000000   3.000000
# mean    83333.333333  35.333333
# std     35118.845843   9.073772
# min     50000.000000  27.000000
# 25%     65000.000000  30.500000
# 50%     80000.000000  34.000000
# 75%    100000.000000  39.500000
# max    120000.000000  45.000000
